# %%
import pandas as pd

# %%
pd.__version__
# Out:
# '0.24.2'

# %% [markdown]
# ### **A estrutura de um DataFrame**

# %%
 df = pd.read_csv("https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv")

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  ...     Fare Cabin  Embarked
# 0            1         0       3  ...   7.2500   NaN         S
# 1            2         1       1  ...  71.2833   C85         C
# 2            3         1       3  ...   7.9250   NaN         S
# 3            4         1       1  ...  53.1000  C123         S
# 4            5         0       3  ...   8.0500   NaN         S
#
# [5 rows x 12 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
# PassengerId    891 non-null int64
# Survived       891 non-null int64
# Pclass         891 non-null int64
# Name           891 non-null object
# Sex            891 non-null object
# Age            714 non-null float64
# SibSp          891 non-null int64
# Parch          891 non-null int64
# Ticket         891 non-null object
# Fare           891 non-null float64
# Cabin          204 non-null object
# Embarked       889 non-null object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.6+ KB

# %% [markdown]
# **Indice**

# %%
df.index
# Out:
# RangeIndex(start=0, stop=891, step=1)

# %% [markdown]
# *Alterando o índice do DataFrame*

# %%
 # df = pd.read_csv("https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv", index_col=0)

# %%
df.set_index('PassengerId', inplace=True)

# %%
df.head()
# Out:
#              Survived  Pclass  ... Cabin Embarked
# PassengerId                    ...
# 1                   0       3  ...   NaN        S
# 2                   1       1  ...   C85        C
# 3                   1       3  ...   NaN        S
# 4                   1       1  ...  C123        S
# 5                   0       3  ...   NaN        S
#
# [5 rows x 11 columns]

# %% [markdown]
# *Colunas*

# %%
df.columns
# Out:
# Index(['Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp', 'Parch', 'Ticket',
#        'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %% [markdown]
# *Valores*

# %%
df.values
# Out:
# array([[0, 3, 'Braund, Mr. Owen Harris', ..., 7.25, nan, 'S'],
#        [1, 1, 'Cumings, Mrs. John Bradley (Florence Briggs Thayer)', ...,
#         71.2833, 'C85', 'C'],
#        [1, 3, 'Heikkinen, Miss. Laina', ..., 7.925, nan, 'S'],
#        ...,
#        [0, 3, 'Johnston, Miss. Catherine Helen "Carrie"', ..., 23.45,
#         nan, 'S'],
#        [1, 1, 'Behr, Mr. Karl Howell', ..., 30.0, 'C148', 'C'],
#        [0, 3, 'Dooley, Mr. Patrick', ..., 7.75, nan, 'Q']], dtype=object)

# %% [markdown]
# *Internamente o Pandas trata dados como Arrays Numpy!*

# %%
type(df)
# Out:
# pandas.core.series.Series

# %% [markdown]
# **DataFrames e Séries**
#
#
# *   Métodos diferentes
# *   N dimesões

# %% [markdown]
# *Consultando dados*

# %% [markdown]
# *Seleciona linhas pelo índice de valor "1"*

# %%
df.head()
# Out:
#              Survived  Pclass  ... Cabin Embarked
# PassengerId                    ...
# 1                   0       3  ...   NaN        S
# 2                   1       1  ...   C85        C
# 3                   1       3  ...   NaN        S
# 4                   1       1  ...  C123        S
# 5                   0       3  ...   NaN        S
#
# [5 rows x 11 columns]

# %%
df.loc[1]
# Out:
# Survived                          0
# Pclass                            3
# Name        Braund, Mr. Owen Harris
# Sex                            male
# Age                              22
# SibSp                             1
# Parch                             0
# Ticket                    A/5 21171
# Fare                           7.25
# Cabin                           NaN
# Embarked                          S
# Name: 1, dtype: object

# %%
type(df.loc[1])
# Out:
# pandas.core.series.Series

# %% [markdown]
# Selecionando várias linhas usando o loc

# %%
df.loc[[1,2,3]]
# Out:
#              Survived  Pclass  ... Cabin Embarked
# PassengerId                    ...
# 1                   0       3  ...   NaN        S
# 2                   1       1  ...   C85        C
# 3                   1       3  ...   NaN        S
#
# [3 rows x 11 columns]

# %% [markdown]
# *Consultando dados usando Slice*

# %%
df.loc[10:20]
# Out:
#              Survived  Pclass  ... Cabin Embarked
# PassengerId                    ...
# 10                  1       2  ...   NaN        C
# 11                  1       3  ...    G6        S
# 12                  1       1  ...  C103        S
# 13                  0       3  ...   NaN        S
# 14                  0       3  ...   NaN        S
# 15                  0       3  ...   NaN        S
# 16                  1       2  ...   NaN        S
# 17                  0       3  ...   NaN        Q
# 18                  1       2  ...   NaN        S
# 19                  0       3  ...   NaN        S
# 20                  1       3  ...   NaN        C
#
# [11 rows x 11 columns]

# %%
df.loc[10:30:2]
# Out:
#              Survived  Pclass  ...        Cabin Embarked
# PassengerId                    ...
# 10                  1       2  ...          NaN        C
# 12                  1       1  ...         C103        S
# 14                  0       3  ...          NaN        S
# 16                  1       2  ...          NaN        S
# 18                  1       2  ...          NaN        S
# 20                  1       3  ...          NaN        C
# 22                  1       2  ...          D56        S
# 24                  1       1  ...           A6        S
# 26                  1       3  ...          NaN        S
# 28                  0       1  ...  C23 C25 C27        S
# 30                  0       3  ...          NaN        S
#
# [11 rows x 11 columns]

# %%
df.loc[10:]

# %% [markdown]
# *Selecionando linhas e Colunas com o loc*

# %% [markdown]
# df.loc[['linha1, linha2], ['coluna1', 'coluna2', 'coluna3']]

# %%
df.loc[[1,2], ['Name','Sex','Age']]
# Out:
#                                                           Name     Sex   Age
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0

# %% [markdown]
# *Slice com linhas e selecionando colunas*

# %%
df.loc[1:10, ['Name','Sex','Age']]
# Out:
#                                                           Name     Sex   Age
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
# 6                                             Moran, Mr. James    male   NaN
# 7                                      McCarthy, Mr. Timothy J    male  54.0
# 8                               Palsson, Master. Gosta Leonard    male   2.0
# 9            Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0
# 10                         Nasser, Mrs. Nicholas (Adele Achem)  female  14.0

# %% [markdown]
# *Selecionando todas as linhas e apenas algumas colunas.*

# %%
df.loc[:, ['Name', 'Sex', 'Age']]

# %% [markdown]
# *Trabalhando com o método query()*

# %%
df.query('Age > 20').head()
# Out:
#              Survived  Pclass  ... Cabin Embarked
# PassengerId                    ...
# 1                   0       3  ...   NaN        S
# 2                   1       1  ...   C85        C
# 3                   1       3  ...   NaN        S
# 4                   1       1  ...  C123        S
# 5                   0       3  ...   NaN        S
#
# [5 rows x 11 columns]

# %%
df.query('Age > 20 & Sex=="male"').head(10)
# Out:
#              Survived  Pclass  ... Cabin Embarked
# PassengerId                    ...
# 1                   0       3  ...   NaN        S
# 5                   0       3  ...   NaN        S
# 7                   0       1  ...   E46        S
# 14                  0       3  ...   NaN        S
# 21                  0       2  ...   NaN        S
# 22                  1       2  ...   D56        S
# 24                  1       1  ...    A6        S
# 31                  0       1  ...   NaN        C
# 34                  0       2  ...   NaN        S
# 35                  0       1  ...   NaN        C
#
# [10 rows x 11 columns]

# %% [markdown]
# **Usando o operador OR **

# %%
df.query('Age > 20 | Sex=="male"').head(10)
# Out:
#              Survived  Pclass  ... Cabin Embarked
# PassengerId                    ...
# 1                   0       3  ...   NaN        S
# 2                   1       1  ...   C85        C
# 3                   1       3  ...   NaN        S
# 4                   1       1  ...  C123        S
# 5                   0       3  ...   NaN        S
# 6                   0       3  ...   NaN        Q
# 7                   0       1  ...   E46        S
# 8                   0       3  ...   NaN        S
# 9                   1       3  ...   NaN        S
# 12                  1       1  ...  C103        S
#
# [10 rows x 11 columns]

# %% [markdown]
# *Operador In  e o parâmetro inplace*

# %%
df.query('Embarked in ["C","Q"]', inplace=True)

# %%
df.head()
# Out:
#              Survived  Pclass  ... Cabin Embarked
# PassengerId                    ...
# 2                   1       1  ...   C85        C
# 6                   0       3  ...   NaN        Q
# 10                  1       2  ...   NaN        C
# 17                  0       3  ...   NaN        Q
# 20                  1       3  ...   NaN        C
#
# [5 rows x 11 columns]

# %% [markdown]
# *Filtrando dados do tipo object*

# %%
df.select_dtypes(include=['float'])
# Out:
#       Age      Fare
# 0    22.0    7.2500
# 1    38.0   71.2833
# 2    26.0    7.9250
# 3    35.0   53.1000
# 4    35.0    8.0500
# 5     NaN    8.4583
# 6    54.0   51.8625
# 7     2.0   21.0750
# 8    27.0   11.1333
# 9    14.0   30.0708
# 10    4.0   16.7000
# 11   58.0   26.5500
# 12   20.0    8.0500
# 13   39.0   31.2750
# 14   14.0    7.8542
# 15   55.0   16.0000
# 16    2.0   29.1250
# 17    NaN   13.0000
# 18   31.0   18.0000
# 19    NaN    7.2250
# 20   35.0   26.0000
# 21   34.0   13.0000
# 22   15.0    8.0292
# 23   28.0   35.5000
# 24    8.0   21.0750
# 25   38.0   31.3875
# 26    NaN    7.2250
# 27   19.0  263.0000
# 28    NaN    7.8792
# 29    NaN    7.8958
# ..    ...       ...
# 861  21.0   11.5000
# 862  48.0   25.9292
# 863   NaN   69.5500
# 864  24.0   13.0000
# 865  42.0   13.0000
# 866  27.0   13.8583
# 867  31.0   50.4958
# 868   NaN    9.5000
# 869   4.0   11.1333
# 870  26.0    7.8958
# 871  47.0   52.5542
# 872  33.0    5.0000
# 873  47.0    9.0000
# ...

# %% [markdown]
# ### Analisando um Dataframe com Profiling

# %%
import pandas_profiling

# %%
pandas_profiling.ProfileReport(df)
# Out:
# <meta charset="UTF-8">
#
# <style>
#
#         .variablerow {
#             border: 1px solid #e1e1e8;
#             border-top: hidden;
#             padding-top: 2em;
#             padding-bottom: 2em;
#             padding-left: 1em;
#             padding-right: 1em;
#         }
#
#         .headerrow {
#             border: 1px solid #e1e1e8;
#             background-color: #f5f5f5;
#             padding: 2em;
#         }
#         .namecol {
#             margin-top: -1em;
#             overflow-x: auto;
#         }
#
#         .dl-horizontal dt {
#             text-align: left;
#             padding-right: 1em;
#             white-space: normal;
#         }
#
#         .dl-horizontal dd {
#             margin-left: 0;
#         }
#
#         .ignore {
#             opacity: 0.4;
#         }
#
#         .container.pandas-profiling {
#             max-width:975px;
#         }
#
#         .col-md-12 {
#             padding-left: 2em;
#         }
#
#         .indent {
# ...

# %% [markdown]
# ### Agregação de Dados

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  ...     Fare Cabin  Embarked
# 0            1         0       3  ...   7.2500   NaN         S
# 1            2         1       1  ...  71.2833   C85         C
# 2            3         1       3  ...   7.9250   NaN         S
# 3            4         1       1  ...  53.1000  C123         S
# 4            5         0       3  ...   8.0500   NaN         S
#
# [5 rows x 12 columns]

# %% [markdown]
# *Agrupa e conta a quantidade por sexo*

# %%
df.groupby(by='Sex').size()
# Out:
# Sex
# female    314
# male      577
# dtype: int64

# %% [markdown]
# *Fazendo a mesma coisa..*

# %%
df.Sex.value_counts()
# Out:
# male      577
# female    314
# Name: Sex, dtype: int64

# %% [markdown]
# *Agrupando por sexo e calculando a média das idades*

# %%
df.groupby(by='Sex')['Age'].mean()
# Out:
# Sex
# female    27.915709
# male      30.726645
# Name: Age, dtype: float64

# %% [markdown]
# *Para trabalhar com os dados use o index e os values*

# %%
s1 = df.groupby(by='Sex')['Age'].mean()

# %%
s1.index.values.tolist()
# Out:
# ['female', 'male']

# %%
s1.values.tolist()
# Out:
# [27.915708812260537, 30.72664459161148]

# %% [markdown]
# *Média das idades das pessoas que sobreviveram e que não sobreviveram.*

# %%
import numpy as np

# %%
df.groupby(['Sex','Survived']).agg({'Age': np.mean, 'PassengerId': np.size})
# Out:
#                        Age  PassengerId
# Sex    Survived
# female 0         25.046875           81
#        1         28.847716          233
# male   0         31.618056          468
#        1         27.276022          109

# %%
df.reset...

# %% [markdown]
# ### Data Cleaning e Pré-processamento de dados

# %% [markdown]
# *Gerando amostras aleatórias dos dados*

# %%
df.sample(n=50).head()
# Out:
#      PassengerId  Survived  Pclass  ...     Fare Cabin  Embarked
# 342          343         0       2  ...  13.0000   NaN         S
# 265          266         0       2  ...  10.5000   NaN         S
# 607          608         1       1  ...  30.5000   NaN         S
# 237          238         1       2  ...  26.2500   NaN         S
# 821          822         1       3  ...   8.6625   NaN         S
#
# [5 rows x 12 columns]

# %% [markdown]
# *25% de dados aleatórios*

# %%
df.sample(frac=.25, random_state=1).head()
# Out:
#      PassengerId  Survived  Pclass  ...     Fare Cabin  Embarked
# 862          863         1       1  ...  25.9292   D17         S
# 223          224         0       3  ...   7.8958   NaN         S
# 84            85         1       2  ...  10.5000   NaN         S
# 680          681         0       3  ...   8.1375   NaN         Q
# 535          536         1       2  ...  26.2500   NaN         S
#
# [5 rows x 12 columns]

# %% [markdown]
# *Tratando Missing Values*

# %%
df.isnull().sum()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Cabin          0
# Embarked       0
# dtype: int64

# %% [markdown]
# ---
#
# Métodos de preenchimento de valores faltantes.
#
# ```
# # df.fillna(0)
# # df.fillna(df.Age.mean())
# # df.fillna(method='ffill')
# # df.fillna(method='bfill')
# # values = {'A': 0, 'B': 1, 'C': 2, 'D': 3} -> df.fillna(value=values)
# ```

# %%
values = {'Age': df.Age.mode()[0], 'Cabin': 'SC', 'Embarked': df.Embarked.mode()[0]}

# %%
# Out:
# 24.0

# %%
df.fillna(value=values, inplace=True)

# %% [markdown]
# *Manipulando strings.*

# %%
df.Name.str.rstrip().head()
# Out:
# 0                              Braund, Mr. Owen Harris
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2                               Heikkinen, Miss. Laina
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4                             Allen, Mr. William Henry
# Name: Name, dtype: object

# %%
df.Name.str.lower().head()
# Out:
# 0                              braund, mr. owen harris
# 1    cumings, mrs. john bradley (florence briggs th...
# 2                               heikkinen, miss. laina
# 3         futrelle, mrs. jacques heath (lily may peel)
# 4                             allen, mr. william henry
# Name: Name, dtype: object

# %%
df.Name.str.upper().head()
# Out:
# 0                              BRAUND, MR. OWEN HARRIS
# 1    CUMINGS, MRS. JOHN BRADLEY (FLORENCE BRIGGS TH...
# 2                               HEIKKINEN, MISS. LAINA
# 3         FUTRELLE, MRS. JACQUES HEATH (LILY MAY PEEL)
# 4                             ALLEN, MR. WILLIAM HENRY
# Name: Name, dtype: object

# %% [markdown]
# *Cleaning textos*

# %%
def remove_parenteses(item):
  if '(' in item:
    return item.replace('(','').replace(')','')
  else:
    return item

# %%
df.Name.head(10).apply(remove_parenteses)
# Out:
# 0                              Braund, Mr. Owen Harris
# 1    Cumings, Mrs. John Bradley Florence Briggs Thayer
# 2                               Heikkinen, Miss. Laina
# 3           Futrelle, Mrs. Jacques Heath Lily May Peel
# 4                             Allen, Mr. William Henry
# 5                                     Moran, Mr. James
# 6                              McCarthy, Mr. Timothy J
# 7                       Palsson, Master. Gosta Leonard
# 8      Johnson, Mrs. Oscar W Elisabeth Vilhelmina Berg
# 9                    Nasser, Mrs. Nicholas Adele Achem
# Name: Name, dtype: object

# %% [markdown]
# *   **Dica**: Método applymap() pode ser usado a nível de dataframe.

# %% [markdown]
# *Usando Expressão regular*

# %%
import re

# %%
df.loc[df.Name.str.contains('Mr', flags=re.I, regex=True)].head()
# Out:
#    PassengerId  Survived  Pclass  ...     Fare Cabin  Embarked
# 0            1         0       3  ...   7.2500    SC         S
# 1            2         1       1  ...  71.2833   C85         C
# 3            4         1       1  ...  53.1000  C123         S
# 4            5         0       3  ...   8.0500    SC         S
# 5            6         0       3  ...   8.4583    SC         Q
#
# [5 rows x 12 columns]

# %% [markdown]
# *Usando lambda*

# %%
def checa_nome(name,last_letter):
  if re.search('Mr', name):
    return last_letter
  else:
    return 0

# %%
df['Mr_name'] =  df.Name.apply(lambda x: checa_nome(x, x[-1]))

# %%
df.head(20)
# Out:
#     PassengerId  Survived  Pclass  ... Cabin Embarked  Mr_name
# 0             1         0       3  ...    SC        S        s
# 1             2         1       1  ...   C85        C        )
# 2             3         1       3  ...    SC        S        0
# 3             4         1       1  ...  C123        S        )
# 4             5         0       3  ...    SC        S        y
# 5             6         0       3  ...    SC        Q        s
# 6             7         0       1  ...   E46        S        J
# 7             8         0       3  ...    SC        S        0
# 8             9         1       3  ...    SC        S        )
# 9            10         1       2  ...    SC        C        )
# 10           11         1       3  ...    G6        S        0
# 11           12         1       1  ...  C103        S        0
# 12           13         0       3  ...    SC        S        y
# 13           14         0       3  ...    SC        S        n
# ...

# %% [markdown]
# ### Trabalhando com grandes bases de dados

# %% [markdown]
# 1.   Tente trabalhar apenas com as colunas que você vai realmente precisar.
# 2.   Atente para o tipo de dado de cada coluna.
# 3.   Use chunksize para dividir o processamento por quantidade de linhas.

# %% [markdown]
# **Dica:** Se estiver no linux use o comando head para ler as 5 primeiras linhas do arquivo:
#
# `head -n 5 dataset.csv`

# %%
# Lear a base com o parâmetro nrows
df = pd.read_csv("https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv", sep=';', nrows=5)

# %%
df

# %% [markdown]
# *Exporte o nome das colunas para usar no parâmetro usecols*

# %%
df.columns.tolist()

# %%
df = pd.read_csv("https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv", usecols=['PassengerId','Survived','Name','Sex'])

# %%
df.head()

# %%
df = pd.read_csv("https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv", usecols=[0,1,2,3,4,5])

# %% [markdown]
# *Veja o uso de memória*

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 8 columns):
# PassengerId    891 non-null int64
# Survived       891 non-null int64
# Pclass         891 non-null int64
# Name           891 non-null object
# Sex            891 non-null object
# Age            714 non-null float64
# SibSp          891 non-null int64
# Embarked       889 non-null object
# dtypes: float64(1), int64(4), object(3)
# memory usage: 55.8+ KB

# %% [markdown]
# *Leia todas as colunas exceto algumas..*

# %%
data = "https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv"
df = pd.read_csv(data, usecols = lambda column : column not in ["Parch" , "Ticket", "Fare","Cabin"])

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  ...   Age SibSp  Embarked
# 0            1         0       3  ...  22.0     1         S
# 1            2         1       1  ...  38.0     1         C
# 2            3         1       3  ...  26.0     0         S
# 3            4         1       1  ...  35.0     1         S
# 4            5         0       3  ...  35.0     0         S
#
# [5 rows x 8 columns]

# %% [markdown]
# ### Trabalhe com os tipos de dados adequados

# %%
df = pd.read_csv("https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv")

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  ...     Fare Cabin  Embarked
# 0            1         0       3  ...   7.2500   NaN         S
# 1            2         1       1  ...  71.2833   C85         C
# 2            3         1       3  ...   7.9250   NaN         S
# 3            4         1       1  ...  53.1000  C123         S
# 4            5         0       3  ...   8.0500   NaN         S
#
# [5 rows x 12 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
# PassengerId    891 non-null int64
# Survived       891 non-null int64
# Pclass         891 non-null int64
# Name           891 non-null object
# Sex            891 non-null object
# Age            714 non-null float64
# SibSp          891 non-null int64
# Parch          891 non-null int64
# Ticket         891 non-null object
# Fare           891 non-null float64
# Cabin          204 non-null object
# Embarked       889 non-null object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.6+ KB

# %% [markdown]
# *Convertendo os tipos de dados*

# %%
df.Sex = df.Sex.astype('category')
df.Embarked = df.Embarked.astype('category')
df.Survived = df.Survived.astype('category')
df.Pclass = df.Pclass.astype('category')
df.PassengerId = df.PassengerId.astype('int32')
df.Parch = df.Parch.astype('int32')
df.SibSp = df.SibSp.astype('int32')

# %% [markdown]
# *Veja o uso de memória*

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
# PassengerId    891 non-null int32
# Survived       891 non-null category
# Pclass         891 non-null category
# Name           891 non-null object
# Sex            891 non-null category
# Age            714 non-null float64
# SibSp          891 non-null int32
# Parch          891 non-null int32
# Ticket         891 non-null object
# Fare           891 non-null float64
# Cabin          204 non-null object
# Embarked       889 non-null category
# dtypes: category(4), float64(2), int32(3), object(3)
# memory usage: 49.2+ KB

# %% [markdown]
# *Converta colunas em tempo de leitura*

# %%
data = "https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv"
df = pd.read_csv(data,  dtype = {"Embarked" : "category", "Survived": "category", "Parch": "int32"})

# %% [markdown]
# ### Trabalhando com Chunksize

# %% [markdown]
# *   O parâmetro chunksize está disponível também para o método **read_json**

# %%
data = "https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv"

# %%
for d in pd.read_csv(data, chunksize=200):
  print ("Chunk")
  print(d.count())
# Out:
# Chunk
# PassengerId    200
# Survived       200
# Pclass         200
# Name           200
# Sex            200
# Age            159
# SibSp          200
# Parch          200
# Ticket         200
# Fare           200
# Cabin           40
# Embarked       199
# dtype: int64
# Chunk
# PassengerId    200
# Survived       200
# Pclass         200
# Name           200
# Sex            200
# Age            163
# SibSp          200
# Parch          200
# Ticket         200
# Fare           200
# Cabin           51
# Embarked       200
# dtype: int64
# Chunk
# PassengerId    200
# Survived       200
# Pclass         200
# Name           200
# Sex            200
# Age            152
# SibSp          200
# Parch          200
# Ticket         200
# Fare           200
# Cabin           46
# Embarked       200
# dtype: int64
# Chunk
# PassengerId    200
# Survived       200
# Pclass         200
# Name           200
# Sex            200
# Age            163
# SibSp          200
# ...

# %%
age_mean = []
age_std = []
sex_dist = []
male_count = []
female_count = []

for d in pd.read_csv("https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv", chunksize=200):
    age_mean.append(d.Age.mean())
    age_std.append(d.Age.std())
    male_count.append(d.Sex.value_counts().values[0])
    female_count.append(d.Sex.value_counts().values[1])

print (age_mean)
print (age_std)
print (male_count)
print (female_count)
# Out:
# [28.017798742138364, 29.33079754601227, 32.11348684210526, 30.12834355828221, 28.275974025974026]
# [15.295229364946692, 13.12020630773483, 14.945121433057423, 14.612669214084448, 14.393209680055847]
# [129, 118, 130, 140, 60]
# [71, 82, 70, 60, 31]
